# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)

x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0
# Out:
# (60000, 28, 28, 1) (10000, 28, 28, 1)
# (60000,) (10000,)

# %%
cnn = Sequential()

cnn.add(Conv2D(input_shape=(28,28,1), kernel_size=(3,3),
              filters=32, activation='relu'))
cnn.add(Conv2D(kernel_size=(3,3), filters=64, activation='relu'))
cnn.add(MaxPool2D(pool_size=(2,2)))
cnn.add(Dropout(0.25))

cnn.add(Flatten())

cnn.add(Dense(128, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10, activation='softmax'))

# %%
cnn.compile(loss='sparse_categorical_crossentropy',
           optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])

cnn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 26, 26, 32)        320
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 12, 12, 64)        0
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 128)               1179776
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 1,199,882
# Trainable params: 1,199,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = cnn.fit(x_train, y_train, batch_size=128,
              epochs=30, validation_data=(x_test, y_test))
# Out:
# Epoch 1/30
# 469/469 [==============================] - 92s 195ms/step - loss: 0.2363 - accuracy: 0.9279 - val_loss: 0.0493 - val_accuracy: 0.9838
# Epoch 2/30
# 469/469 [==============================] - 96s 205ms/step - loss: 0.0832 - accuracy: 0.9756 - val_loss: 0.0409 - val_accuracy: 0.9863
# Epoch 3/30
# 469/469 [==============================] - 95s 204ms/step - loss: 0.0641 - accuracy: 0.9807 - val_loss: 0.0329 - val_accuracy: 0.9882
# Epoch 4/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0505 - accuracy: 0.9841 - val_loss: 0.0319 - val_accuracy: 0.9889
# Epoch 5/30
# 469/469 [==============================] - 95s 203ms/step - loss: 0.0426 - accuracy: 0.9870 - val_loss: 0.0319 - val_accuracy: 0.9893
# Epoch 6/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0409 - accuracy: 0.9871 - val_loss: 0.0266 - val_accuracy: 0.9923
# Epoch 7/30
# 469/469 [==============================] - 94s 201ms/step - loss: 0.0340 - accuracy: 0.9890 - val_loss: 0.0283 - val_accuracy: 0.9910
# Epoch 8/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0312 - accuracy: 0.9898 - val_loss: 0.0290 - val_accuracy: 0.9913
# Epoch 9/30
# 469/469 [==============================] - 98s 208ms/step - loss: 0.0272 - accuracy: 0.9914 - val_loss: 0.0302 - val_accuracy: 0.9909
# Epoch 10/30
# 469/469 [==============================] - 95s 203ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 0.0301 - val_accuracy: 0.9916
# Epoch 11/30
# 469/469 [==============================] - 94s 201ms/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 0.0268 - val_accuracy: 0.9913
# Epoch 12/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.0316 - val_accuracy: 0.9918
# Epoch 13/30
# 469/469 [==============================] - 94s 201ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.0285 - val_accuracy: 0.9917
# Epoch 14/30
# 469/469 [==============================] - 95s 203ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0274 - val_accuracy: 0.9927
# Epoch 15/30
# 469/469 [==============================] - 97s 207ms/step - loss: 0.0159 - accuracy: 0.9945 - val_loss: 0.0337 - val_accuracy: 0.9911
# Epoch 16/30
# 469/469 [==============================] - 97s 206ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.0307 - val_accuracy: 0.9924
# Epoch 17/30
# 469/469 [==============================] - 96s 205ms/step - loss: 0.0142 - accuracy: 0.9951 - val_loss: 0.0311 - val_accuracy: 0.9918
# Epoch 18/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0141 - accuracy: 0.9951 - val_loss: 0.0321 - val_accuracy: 0.9924
# Epoch 19/30
# 469/469 [==============================] - 94s 201ms/step - loss: 0.0134 - accuracy: 0.9956 - val_loss: 0.0318 - val_accuracy: 0.9919
# Epoch 20/30
# 469/469 [==============================] - 93s 199ms/step - loss: 0.0115 - accuracy: 0.9962 - val_loss: 0.0327 - val_accuracy: 0.9920
# Epoch 21/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.0301 - val_accuracy: 0.9939
# Epoch 22/30
# 469/469 [==============================] - 97s 207ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0317 - val_accuracy: 0.9922
# Epoch 23/30
# 469/469 [==============================] - 94s 200ms/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0358 - val_accuracy: 0.9916
# Epoch 24/30
# 469/469 [==============================] - 95s 202ms/step - loss: 0.0113 - accuracy: 0.9961 - val_loss: 0.0290 - val_accuracy: 0.9941
# Epoch 25/30
# 469/469 [==============================] - 94s 201ms/step - loss: 0.0113 - accuracy: 0.9962 - val_loss: 0.0310 - val_accuracy: 0.9932
# Epoch 26/30
# 469/469 [==============================] - 94s 200ms/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.0315 - val_accuracy: 0.9937
# Epoch 27/30
# 469/469 [==============================] - 101s 215ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0338 - val_accuracy: 0.9926
# Epoch 28/30
# 469/469 [==============================] - 100s 213ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.0289 - val_accuracy: 0.9942
# Epoch 29/30
# 469/469 [==============================] - 99s 211ms/step - loss: 0.0098 - accuracy: 0.9965 - val_loss: 0.0310 - val_accuracy: 0.9932
# Epoch 30/30
# 469/469 [==============================] - 100s 212ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0318 - val_accuracy: 0.9930

# %%
cnn.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step - loss: 0.0318 - accuracy: 0.9930
# [0.03184640035033226, 0.9929999709129333]

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy Trend')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='best')
plt.grid()
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss Trend')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='best')
plt.grid()
plt.show()
